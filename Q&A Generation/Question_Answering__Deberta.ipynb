# %% [markdown]
# ##**Load Data**

# %%
import pandas as pd

df = pd.read_csv('Q&A Generator.csv')
df
# Out:
#                                                Context  \
# 0    A subset of machine learning is closely relate...
# 1    A subset of machine learning is closely relate...
# 2    domains to the field of machine learning,  Som...
# 3    learning use data and neural networks in a way...
# 4     of a biological brain,  machine learning is a...
# ..                                                 ...
# 233  alities in the data and react based on the pre...
# 234  g or as a preprocessing step to improve learne...
# 235  rning encompasses other domains involving summ...
# 236  tween unsupervised learning without any labele...
# 237  tween unsupervised learning without any labele...
#
#                                               Question  \
# 0    What is a subset of machine learning closely r...
# 1    What is not all machine learning statistical l...
# 2    Some implementations of what use data and neur...
# 3                    What does machine learning mimic?
# 4        What is machine learning also referred to as?
# ..                                                 ...
# 233  Unsupervised learning algorithms identify comm...
# 234  What is a central application of unsupervised ...
# 235  Unsupervised learning encompasses other domain...
# 236  Semisupervised learning falls under what categ...
# 237  Semisupervised learning falls between unsuperv...
#
#                                        Haystack_Answer
# 0                             computational statistics
# 1    A subset of machine learning is closely relate...
# 2                                     machine learning
# 3                    the working of a biological brain
# 4                                 predictive analytics
# ..                                                 ...
# 233                                 such commonalities
# 234                   unsupervised learning algorithms
# 235                                      data features
# 236  unsupervised learning without any labeled trai...
# 237                   completely labeled training data
#
# [238 rows x 3 columns]

# %% [markdown]
# ##**Deberta**

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.22.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.9.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)

# %%
# batch_size = 2
# grad_acc_steps = 32
# n_epochs = 6
# base_LM_model = "microsoft/deberta-v3-large"
# max_seq_len = 512
# learning_rate = 7e-6
# # lr_schedule = LinearWarmup()
# warmup_proportion = 0.2
# doc_stride=128
# max_query_length=64

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

model_name = "deepset/deberta-v3-large-squad2"

# a) Get predictions
nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)

# %%
deberta_ans = []
for q, c in zip(df['Question'], df['Context']):
  QA_input = {
      'question': q,
      'context': c
  }
  # print(nlp(QA_input)['answer'])
  deberta_ans.append(nlp(QA_input)['answer'])

df['Deberta_Answer']=deberta_ans
# Out:
#  computational statistics,
#  statistics,
#  machine learning
#  a biological brain,
#  predictive analytics,
#  Supportvector machines SVMs,
#  deep learning
#  Arthur Samuel,
#  an experimental learning machine
#  Nilssons book on Learning Machines,
#  machine learning for pattern classification,
#  some class of tasks
#  generalizable predictive patterns,
#  Can machines do what we as thinking entities can do,
#  two
#  the trader of future potential predictions,
#  future potential predictions,
#  machine learning
#  data,
#  knowledgebased approach
#  Data mining
#  unsupervised learning
#  the basic assumptions they work with in machine learning,
#  the goal of generalization
#  loss
#  optimization
#  machine learning
#  computational learning theory
#  computational analysis of machine learning algorithms
#  regression and classification,
#  Reinforcement learning
#  Reinforcement learning
#  deep learning
#  in along with a neural network
#  machine learning paradigm
#  deep learning
#  learn the features and use them to perform a specific task,
#  a representation
#  Feature learning
#  machine learning methods,
#  Association rule learning
#  Rulebased machine learning
#  Rulebased machine learning
#  identification and utilization of a set of relational rules
#  Rulebased machine learning approaches
#  rulebased machine learning algorithms
#  a family of rulebased machine learning algorithms that combine a discovery component,
#  Gordon Plotkin and Ehud Shapiro
#  machine learning
#  machine learning systems,  machine translation,  and machine learning,
#  a high quantity of reliable data
#  data,
#  Overfitting
#  Machine learning ethics
#  Machine learning ethics
# Federated learning
#  Rebellion Research
#  machine learning
#  predictive analytics,
#  next
#  art history
#  art history
#  Springer Nature
#  diagnoses
#  COVID,
#  based on the users interaction with the phone,
#  deep learning has become the dominant approach for much ongoing work in the field
#  expected results,
#  IBM Watson
#  billions of dollars
#  training data,
#  constitutional and unconscious biases
#  fairness
#  Machine learning models
#  by third parties,
#  machine learning models
#  Using job hiring data from a firm with racist hiring policies
#  Using job hiring data from a firm with racist hiring policies
#  prediction,
#  language corpora
#  language corpora
#  the publics interest
#  provide professionals an additional tool to diagnose,
#  neural network capable of selflearning,
#  nonlinear hidden units,
#  computational statistics,
#  machine learning model
#  cloud servers
#  Free and opensource software Proprietary software with free and opensource edition
#  Software suites
#  Proprietary software
#  K
#  CIBB International Conference on Machine Learning
#  KDD
#  Big data
#  Differentiable programming
#  opensource machine learning software
#  International Machine Learning Society
#  computational statistics,
#  statistics,
#  machine learning
#  predictive analytics,
#  tasks
#  Arthur Samuel,
#  Nilssons book on Learning Machines,
# ram
#  statistics,
#  a fundamentally operational definition
#  two
#  future potential predictions,
#  knowledgebased approach
#  prediction,
#  neural networks
#  Knowledge Discovery and Data Mining KDD Conference on Neural Information Processing Systems NeurIPS
#  Generalization
#  the goal of generalization
#  generalization
#  minimizing the loss on unseen samples,
#  machine learning
#  machine learning,
#  computational analysis of machine learning algorithms
#  Similarity learning
#  regression and classification,
#  machine learning
#  deep learning
#  inductive
#  machine learning paradigm
#  selflearning
#  Feature learning
#  machine learning methods,
#  machine learning methods,
#  Robot learning
#  Rulebased machine learning
#  utilization of a set of relational rules
# knowledge captured by the system,
#  rulebased machine learning algorithms
#  a family of rulebased machine learning algorithms that combine a discovery component,
#  LCS are a family of rulebased machine learning algorithms
#  Gordon Plotkin and Ehud Shapiro
#  Performing machine learning
#  genetic and evolutionary algorithms,
#  a high quantity of reliable data
#  genetic and evolutionary
#  machine learning models require a high quantity of reliable data
# arge and representative sample of data,
#  Overfitting
#  Machine learning ethics
#  an adapted form of distributed artificial intelligence to training machine learning models
#  search query prediction models
#  federated machine learning
#  Rebellion Research
#  jobs would be lost
#  Rebellion Research
#  m
#  field of art history
#  Springer Nature
#  machine learning technology
#  machine learning
#  smartphones performance
#  IBM Watson system
#  new customer groups
#  machine learning
#  the effective use of machine learning
#  Concern for fairness in machine learning,  reducing bias in machine learning
#  adversarial machine learning,
#  Machine learning models
#  machine learning models
#  machine learning models
#  Using job hiring data from a firm with racist hiring policies
#  prediction,
#  provide professionals an additional tool to diagnose,
#  advances in both machine learning algorithms and computer hardware
#  machine learning,
#  computational statistics,
#  embedded systems
#  Running machine learning model in embedded devices
#  Running machine learning model in embedded devices
#  Proprietary software with free and opensource editions
#  Proprietary software
#  KNIME RapidMiner
#  CIBB International Conference on Machine Learning
#  IROS
#  KDD
#  opensource machine learning software
#  International Machine Learning Society mloss
#  computational analysis of machine learning algorithms
#  computational learning theory
#  Learning classifier systems
#  rulebased machine learning algorithms
#  Learning classifier systems LCS
# advances in both machine learning algorithms
#  nonlinear hidden units,
# tworks
#  Proprietary software with free and opensource editions KNIME
#  Proprietary software with free and opensource ed
# rning Research Machine Learning Nature Machine Intelligence Neural Computation Conferences
# B International Conference on Machine Learning
#  KDD
#  Software
#  Big data
#  Robot learning is inspired by a multitude of machine learning methods
#  machine learning methods
#  reliable
#  distributed artificial intelligence
#  third parties,
#  machine learning models
#  holdout method,
#  accuracy estimation techniques
#  data and neural networks
#  perceptrons and other models
#  computing systems
#  biological neural networks
#  animal brains,
#  machine learning
#  a particular narrow subdomain of machine learning that contain many layers of nonlinear hidden unit
#  nonlinear
#  nonlinear hidden units,
#  th
#  training data,
#  to improve the algorithms
#  unavailability of training data,
#  supervised methods
#  a matrix,
#  the training data,
#  Semisupervised
#  normal behavior
#  current customers
#  the needs of new customer groups that are not represented in the training data,
#  workaround
#  Google
#  overfitting
#  exploratory data analysis
# unsupervised learning
#  commonalities
#  as a preprocessing step to improve learner accuracy,
#  data features,
#  unsupervised
#  completely labeled training data,

# %% [markdown]
# ##**Save Data in The CSV File**

# %%
# Save dataframe as csv file in the current folder
df.to_csv('Q&A Generator.csv', index = False, encoding='utf-8') # False: not include index

# %%
df
# Out:
#                                                Context  \
# 0    A subset of machine learning is closely relate...
# 1    A subset of machine learning is closely relate...
# 2    domains to the field of machine learning,  Som...
# 3    learning use data and neural networks in a way...
# 4     of a biological brain,  machine learning is a...
# ..                                                 ...
# 233  alities in the data and react based on the pre...
# 234  g or as a preprocessing step to improve learne...
# 235  rning encompasses other domains involving summ...
# 236  tween unsupervised learning without any labele...
# 237  tween unsupervised learning without any labele...
#
#                                               Question  \
# 0    What is a subset of machine learning closely r...
# 1    What is not all machine learning statistical l...
# 2    Some implementations of what use data and neur...
# 3                    What does machine learning mimic?
# 4        What is machine learning also referred to as?
# ..                                                 ...
# 233  Unsupervised learning algorithms identify comm...
# 234  What is a central application of unsupervised ...
# 235  Unsupervised learning encompasses other domain...
# 236  Semisupervised learning falls under what categ...
# 237  Semisupervised learning falls between unsuperv...
#
#                                        Haystack_Answer  \
# 0                             computational statistics
# 1    A subset of machine learning is closely relate...
# 2                                     machine learning
# 3                    the working of a biological brain
# 4                                 predictive analytics
# ..                                                 ...
# 233                                 such commonalities
# 234                   unsupervised learning algorithms
# 235                                      data features
# 236  unsupervised learning without any labeled trai...
# 237                   completely labeled training data
#
#                                         Deberta_Answer
# 0                            computational statistics,
# 1                                          statistics,
# 2                                     machine learning
# 3                                  a biological brain,
# 4                                predictive analytics,
# ..                                                 ...
# 233                                      commonalities
# 234   as a preprocessing step to improve learner ac...
# 235                                     data features,
# 236                                       unsupervised
# 237                  completely labeled training data,
#
# [238 rows x 4 columns]
